# %%
pwd
# Out:
# '/glade/u/home/jzweifel/jupyter_workspaces/Masters_paper_analysis/CESM_historical'

# %%
import xarray as xr

area = xr.open_dataarray('old_Regional_masks_and_area/area_files/AREA.nc')
# netcdf of grid cell areas

CJK_mask = xr.open_dataarray('old_Regional_masks_and_area/masks/CJK/CJK_binary_assign_coords.nc')
NPO_mask = xr.open_dataarray('area_weighted_NPO_lower_bound_20_deg.nc')
# Binary mask for East Asia and an area-weighted mask for North Pacific Ocean with lower bound of 20°N

SFSO2 = xr.open_dataset('b.e21.BHIST.f09_g17.CMIP6-historical.003.cam.h0.SFSO2.185001-201412.nc')['SFSO2'].where(CJK_mask) * area
# SO2 surface flux, kg/m2/s
# masked to East Asia and multiplied by grid cell area

SO2_CMXF = xr.open_dataset('b.e21.BHIST.f09_g17.CMIP6-historical.003.cam.h0.SO2_CMXF.185001-201412.nc')['SO2_CMXF'].where(CJK_mask) * area
# Vertically integrated external forcing for SO2, kg/m2/s
# masked to East Asia and multiplied by grid cell area

total_SO2_from_surface_and_column_ = SFSO2 + SO2_CMXF


AODSO4dn = xr.open_dataset('b.e21.BHIST.f09_g17.CMIP6-historical.003.cam.h0.AODSO4dn.185001-201412.nc')['AODSO4dn'].where(NPO_mask)
# Aerosol optical depth 550 nm from SO4, day night
# Masked by area weighted NPO mask

# %%
def return_list_of_months(ds, months, operation):
    to_fill = []
    for month in months: 
        if operation =='sum':
            filling = ds.sel(time=ds.time[ds.time.dt.month == month]).sum(dim=['lat', 'lon'])
            to_fill.append(filling)
        elif operation =='mean':
            filling = ds.sel(time=ds.time[ds.time.dt.month == month]).mean(dim=['lat', 'lon'])
            to_fill.append(filling)
    return to_fill

months_total_SO2_from_surface_and_column_ = return_list_of_months(total_SO2_from_surface_and_column_, [3,6,9,12], 'sum') 
# returns the total sum of SO2 flux from East Asia

months_AODSO4dn = return_list_of_months(AODSO4dn, [3,6,9,12], 'mean')
# returns the spatial average of NPO AODSO4

# %%
import matplotlib.pyplot as plt

# Match each label to a color based on seasonal perception
labels = ['Feb', 'May', 'Aug', 'Nov']
label_to_color = {
    'Feb': "#1E90FF",  # Cool winter blue
    'May': "#32CD32",  # Fresh spring green
    'Aug': "#C70039",  # Hot summer red
    'Nov': "#FF8C00"   # Warm autumn orange
}

seconds_per_year = 60 * 60 * 24 * 365
Kg_to_Tg = 1e-9
S_SO4_ratio = 32.065/115.107

fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharex=True)

# Plot sulfur fluxes (Tg SO4/year)
for i, label in zip(months_total_SO2_from_surface_and_column_, labels):
    axs[0].plot(
        i.time.dt.year,
        i * seconds_per_year * Kg_to_Tg * S_SO4_ratio,
        label=label,
        color=label_to_color[label],
        linewidth=2
    )
axs[0].set_ylabel('Tg Sulfur / year', fontsize=12)
axs[0].set_title('Total Sulfur flux (Surface + Aloft) over East Asia', fontsize=14)
axs[0].grid(linestyle='--', alpha=0.6)
axs[0].legend(title='Month', fontsize=10, loc="upper left")

# Plot sulfate AOD
for j, label in zip(months_AODSO4dn, labels):
    axs[1].plot(
        j.time.dt.year,
        j * 100,
        label=label,
        color=label_to_color[label],
        linewidth=2
    )
axs[1].set_ylabel("AOD × 100", fontsize=12)
axs[1].set_title("Sulfate Aerosol Optical Depth over the North Pacific", fontsize=14)
axs[1].grid(linestyle='--', alpha=0.6)
axs[1].legend(title='Month', fontsize=10, loc="upper left")

plt.tight_layout()
plt.show()

# %% [raw]
# def scale_by_area_and_mask(dataset, area, mask):
#     '''This function takes a dataarray and scales it by grid cell area.
#        A binary mask is also applied after scaling by area.
#        The area-scaled and masked dataset is returned.
#     '''
#     return dataset * area * mask
#
# def split_dataarray_by_month(data_array, month1, month2, month3, month4):
#     month1_data = data_array.sel(time=data_array.time.dt.month==month1)
#     month2_data = data_array.sel(time=data_array.time.dt.month==month2)
#     month3_data = data_array.sel(time=data_array.time.dt.month==month3)
#     month4_data = data_array.sel(time=data_array.time.dt.month==month4)
#     return month1_data, month2_data, month3_data, month4_data
#
# def apply_mask_to_dataarray(full_data_array, masked_array):
#     applied_mask = full_data_array*masked_array
#     return applied_mask.where(applied_mask>0, drop=True)

# %% [raw]
# area_scaled_and_masked_SO2_CMXF = scale_by_area_and_mask(SO2_CMXF, area, CJK_binary_mask)
#
# feb_SO2_CMXF,may_SO2_CMXF,aug_SO2_CMXF,nov_SO2_CMXF = split_dataarray_by_month(area_scaled_and_masked_SO2_CMXF,3,6,9,12)
#
# area_scaled_and_masked_SFSO2 = scale_by_area_and_mask(SFSO2, area, CJK_binary_mask)
#
# feb_SFSO2,may_SFSO2,aug_SFSO2,nov_SFSO2 = split_dataarray_by_month(area_scaled_and_masked_SFSO2,3,6,9,12)

# %% [raw]
# area_weighted_NPO_mask = xr.open_dataarray('/glade/derecho/scratch/jzweifel/Regional_Masks_And_Area/masks/NPO/area_weighted_NPO_mask.nc')
#
# NPO_AODSO4dn = apply_mask_to_dataarray(AODSO4dn, area_weighted_NPO_mask)
#
# Feb_AODSO4dn, May_AODSO4dn, Aug_AODSO4dn, Nov_AODSO4dn = split_dataarray_by_month(NPO_AODSO4dn, 2,5,8,11)

# %% [raw]
# time = feb_SFSO2.time.dt.year
# seconds_per_year = 60 * 60 * 24 * 365
# Kg_to_Tg = 1e-9
# S_SO4_ratio = 32.065/115.107

# %% [raw]
# import matplotlib.pyplot as plt
#
# fig, axs = plt.subplots(1, 2, figsize=(15, 5))
#
# # Define improved seasonal colors
# colors = {
#     "February": "#1E90FF",  # Cooler blue
#     "May": "#32CD32",       # Lively spring green
#     "August": "#C70039",    # Hot red
#     "November": "#FF8C00"   # Warm autumn orange
# }
#
# feb_emissions = ((feb_SO2_CMXF + feb_SFSO2) * seconds_per_year * Kg_to_Tg * S_SO4_ratio).sum(dim=['lat', 'lon'])
# may_emissions = ((may_SO2_CMXF + may_SFSO2) * seconds_per_year * Kg_to_Tg * S_SO4_ratio).sum(dim=['lat', 'lon'])
# aug_emissions = ((aug_SO2_CMXF + aug_SFSO2) * seconds_per_year * Kg_to_Tg * S_SO4_ratio).sum(dim=['lat', 'lon'])
# nov_emissions = ((nov_SO2_CMXF + nov_SFSO2) * seconds_per_year * Kg_to_Tg * S_SO4_ratio).sum(dim=['lat', 'lon'])
#
# feb_AOD = Feb_AODSO4dn.mean(dim=['lat', 'lon']) * 100
# may_AOD = May_AODSO4dn.mean(dim=['lat', 'lon']) * 100
# aug_AOD = Aug_AODSO4dn.mean(dim=['lat', 'lon']) * 100
# nov_AOD = Nov_AODSO4dn.mean(dim=['lat', 'lon']) * 100
#
# # Define common styles
# line_styles = {'linewidth': 5, 'alpha': 1}
#
# # Left plot: Sulfur Emissions
# axs[0].plot(time, feb_emissions, color=colors["February"], label='FEB', **line_styles)
# axs[0].plot(time, may_emissions, color=colors["May"], label='MAY', **line_styles)
# axs[0].plot(time, aug_emissions, color=colors["August"], label='AUG', **line_styles)
# axs[0].plot(time, nov_emissions, color=colors["November"], label='NOV', **line_styles)
#
# axs[0].set_ylabel('Teragrams Sulfur per Year', fontsize=12)
# axs[0].set_title('Total External Sulfur Flux (Surface + Column) over East Asia', fontsize=14)
# axs[0].grid(linestyle='--', alpha=0.6)
# axs[0].legend(fontsize=10, loc="upper left")
#
# # Right plot: Aerosol Optical Depth
# axs[1].plot(time, feb_AOD, color=colors["February"], label='FEB', **line_styles)
# axs[1].plot(time, may_AOD, color=colors["May"], label='MAY', **line_styles)
# axs[1].plot(time, aug_AOD, color=colors["August"], label='AUG', **line_styles)
# axs[1].plot(time, nov_AOD, color=colors["November"], label='NOV', **line_styles)
#
# axs[1].set_xlabel("Year", fontsize=12)
# axs[1].set_ylabel("Aerosol Optical Depth * 100", fontsize=12)  # Clarified unit
# axs[1].set_title("Sulfate Aerosol Optical Depth over the North Pacific", fontsize=14)
# axs[1].grid(linestyle='--', alpha=0.6)
# axs[1].legend(fontsize=10, loc="upper left")
#
#
# # Adjust layout for better spacing
# plt.tight_layout()
# plt.show()

# %% [raw]
# import matplotlib.pyplot as plt
#
# fig, axs = plt.subplots(2, 2, figsize=(15, 10))  # Now we have 2 rows
#
# # Define improved seasonal colors
# colors = {
#     "February": "#1E90FF",  # Cooler blue
#     "May": "#32CD32",       # Lively spring green
#     "August": "#C70039",    # Hot red
#     "November": "#FF8C00"   # Warm autumn orange
# }
#
# # Define common styles
# line_styles = {'linewidth': 5, 'alpha': 1}
#
# # Left plot: Sulfur Emissions
# feb_emissions = ((feb_SO2_CMXF + feb_SFSO2) * seconds_per_year * Kg_to_Tg * S_SO4_ratio).sum(dim=['lat', 'lon'])
# may_emissions = ((may_SO2_CMXF + may_SFSO2) * seconds_per_year * Kg_to_Tg * S_SO4_ratio).sum(dim=['lat', 'lon'])
# aug_emissions = ((aug_SO2_CMXF + aug_SFSO2) * seconds_per_year * Kg_to_Tg * S_SO4_ratio).sum(dim=['lat', 'lon'])
# nov_emissions = ((nov_SO2_CMXF + nov_SFSO2) * seconds_per_year * Kg_to_Tg * S_SO4_ratio).sum(dim=['lat', 'lon'])
#
# axs[0, 0].plot(time, feb_emissions, color=colors["February"], label='FEB', **line_styles)
# axs[0, 0].plot(time, may_emissions, color=colors["May"], label='MAY', **line_styles)
# axs[0, 0].plot(time, aug_emissions, color=colors["August"], label='AUG', **line_styles)
# axs[0, 0].plot(time, nov_emissions, color=colors["November"], label='NOV', **line_styles)
#
# axs[0, 0].set_ylabel('Teragrams Sulfur per Year', fontsize=12)
# axs[0, 0].set_title('Total External Sulfur Flux (Surface + Column) over East Asia', fontsize=14)
# axs[0, 0].grid(linestyle='--', alpha=0.6)
# axs[0, 0].legend(fontsize=10, loc="upper left")
#
# # Right plot: Aerosol Optical Depth
# feb_AOD = Feb_AODSO4dn.mean(dim=['lat', 'lon']) * 100
# may_AOD = May_AODSO4dn.mean(dim=['lat', 'lon']) * 100
# aug_AOD = Aug_AODSO4dn.mean(dim=['lat', 'lon']) * 100
# nov_AOD = Nov_AODSO4dn.mean(dim=['lat', 'lon']) * 100
#
# axs[0, 1].plot(time, feb_AOD, color=colors["February"], label='FEB', **line_styles)
# axs[0, 1].plot(time, may_AOD, color=colors["May"], label='MAY', **line_styles)
# axs[0, 1].plot(time, aug_AOD, color=colors["August"], label='AUG', **line_styles)
# axs[0, 1].plot(time, nov_AOD, color=colors["November"], label='NOV', **line_styles)
#
# axs[0, 1].set_xlabel("Year", fontsize=12)
# axs[0, 1].set_ylabel("Aerosol Optical Depth * 100", fontsize=12)
# axs[0, 1].set_title("Sulfate Aerosol Optical Depth over the North Pacific", fontsize=14)
# axs[0, 1].grid(linestyle='--', alpha=0.6)
# axs[0, 1].legend(fontsize=10, loc="upper left")
#
# # Bottom Left: Relative Ratios of Sulfur Emissions (Compared to February)
# axs[1, 0].plot(time, may_emissions.values / feb_emissions.values, color=colors["May"], label='MAY / FEB', **line_styles)
# axs[1, 0].plot(time, aug_emissions.values / feb_emissions.values, color=colors["August"], label='AUG / FEB', **line_styles)
# axs[1, 0].plot(time, nov_emissions.values / feb_emissions.values, color=colors["November"], label='NOV / FEB', **line_styles)
#
# axs[1, 0].set_ylabel('Relative Ratio', fontsize=12)
# axs[1, 0].set_title('Sulfur Emission Ratios (Compared to February)', fontsize=14)
# axs[1, 0].grid(linestyle='--', alpha=0.6)
# axs[1, 0].axhline(y=1, color='black', linestyle='--', alpha=0.7)  # Reference line at 1
# axs[1, 0].legend(fontsize=10, loc="upper left")
#
# # Bottom Right: Relative Ratios of AOD (Compared to February)
# axs[1, 1].plot(time, may_AOD.values / feb_AOD.values, color=colors["May"], label='MAY / FEB', **line_styles)
# axs[1, 1].plot(time, aug_AOD.values / feb_AOD.values, color=colors["August"], label='AUG / FEB', **line_styles)
# axs[1, 1].plot(time, nov_AOD.values / feb_AOD.values, color=colors["November"], label='NOV / FEB', **line_styles)
#
# axs[1, 1].set_ylabel('Relative Ratio', fontsize=12)
# axs[1, 1].set_title('AOD Ratios (Compared to February)', fontsize=14)
# axs[1, 1].grid(linestyle='--', alpha=0.6)
# axs[1, 1].axhline(y=1, color='black', linestyle='--', alpha=0.7)  # Reference line at 1
# axs[1, 1].legend(fontsize=10, loc="upper left")
#
# # Adjust layout for better spacing
# plt.tight_layout()
# plt.show()

# %% [raw]
# print((may_AOD.values/feb_AOD.values)[-20:].mean())
#
# print((may_emissions.values/feb_emissions.values)[-20:].mean())
